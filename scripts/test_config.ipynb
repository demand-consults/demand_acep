# %% [markdown]
# ## This file helps test the config file

# %%
# ALl the imports
import os, sys
import pandas as pd

# %%
# Add the path of pour module to the system path
module_path = os.path.abspath(os.path.join('..', 'demand_acep'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# Import the config
import config

# %%
type(config)
# Out:
# module

# %%
import inspect
from pprint import pprint

# %%
inspect.getcomments(config)
# Out:
# '# This file has the global configuration \n# so we do not have to repeat those in every function \n'

# %%
pprint(vars(config))
# Out:
# {'DATA_ROOT': None,
#  'DATA_YEARS': [2017, 2018, 2019],
#  'DATA_YEARS_FILE': '/home/ubuntu/demand_acep/demand_acep/data/properties/data_years.txt',
#  'DB_NAME': 'demand_acep',
#  'INTERP_METHOD': 'spline',
#  'INTERP_ORDER': 2,
#  'METADATA_PATH': '/home/ubuntu/demand_acep/demand_acep/data/properties/',
#  'METER_CHANNEL_DICT': {'PQube3': ['time',
#                                    'Van',
#                                    'Vbn',
#                                    'Vcn',
#                                    'Vab',
#                                    'Vbc',
#                                    'Vca',
#                                    'F',
#                                    'Ia',
#                                    'Ib',
#                                    'Ic',
#                                    'PTot',
#                                    'Pa',
#                                    'Pb',
#                                    'Pc',
# ...

# %%
type(vars(config))
# Out:
# dict
